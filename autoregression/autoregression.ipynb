# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pandas.plotting import autocorrelation_plot
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from statsmodels.tsa.stattools import adfuller, kpss

# %%
data = pd.read_csv('../daily-min-temperatures.csv', 
                   header=0, 
                   index_col=0, 
                   parse_dates=True)

# %%
data.plot();

# %% [markdown]
# ### Conduct ADF test to check for stationarity of time series

# %%
stat, p_val, _, _, _, _  = adfuller(data)
print(f'Statistic: {stat}; p-value: {p_val}')
# Out:
# Statistic: -4.444804924611684; p-value: 0.0002470826300361156

# %% [markdown]
# #### $p < 0.05 \Rightarrow $ reject $H_0$.

# %% [markdown]
# ### Conduct KPSS test to check for stationarity

# %%
stat, p_val, _, _ = kpss(data)
print(f'Statistic: {stat}; p-value: {p_val}')
# Out:
# Statistic: 0.05570612670427433; p-value: 0.1
# /var/folders/1s/tsdn68ps7_sc32ggkmy293y80000gn/T/ipykernel_1184/3032710347.py:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   stat, p_val, _, _ = kpss(data)

# %% [markdown]
# #### $p > 0.05 \Rightarrow $ do not reject $H_0$

# %% [markdown]
# ### Both test show that our time series is stationary

# %% [markdown]
# ### Check for autocorrelation of our time series

# %%
autocorr = pd.concat([data.shift(1), data], axis=1)
autocorr.columns = ['t+1', 't-1']
autocorr.corr()
# Out:
#          t+1      t-1
# t+1  1.00000  0.77487
# t-1  0.77487  1.00000

# %%
autocorrelation_plot(data);

# %% [markdown]
# ### Build class for AR model using sklearn linreg

# %%
# TODO: Implement class
class AutoRegression:
    def __init__(self, lags: int) -> None:
        self.lags = lags
        self.model = LinearRegression(n_jobs=-1)
        
    
    def fit(self, X) -> None:
        for x in range(X.shape):
            pass
    
    def predict(self) -> np.ndarray:
        pass

# %%
data

# %%
len(data.values[5:data.shape[0]-5])
# Out:
# 3640
